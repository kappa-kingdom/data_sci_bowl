# %%
from IPython.display import display,HTML

import pandas as pd
import numpy as np
import os

pd.set_option('display.max_colwidth' , -1)

# %%
data_path = "/media/dark_lord/study/data_science/kaggle_compitions/data/data_sci_bowl"
os.chdir(data_path)

# %%
os.listdir()
# Out:
# ['sample_submission.csv',
#  'specs.csv',
#  'test.csv',
#  'train.csv',
#  'train_labels.csv',
#  'train_sample.csv']

# %% [markdown]
# Create a sample train.csv as original is 3.9 GB

# %%
# !grep -ir 9501794defd84e4d train.csv > train_sample.csv

# %%
# !head -1 train.csv > header_train.csv

# %%
# !cat header_train.csv train_sample.csv > train_sample_2.csv

# %%
# %%time
sample_submission = pd.read_csv("sample_submission.csv")
specs = pd.read_csv("specs.csv")
test = pd.read_csv("test.csv")
train_sample = pd.read_csv("train_sample_2.csv")
train_labels = pd.read_csv("train_labels.csv")
# Out:
# CPU times: user 6.18 s, sys: 408 ms, total: 6.59 s
# Wall time: 9.09 s

# %% [markdown]
# took a sample game session -- 9501794defd84e4d of installation_id -- 0006a69f

# %%
print("test----")
display(test[test['installation_id']=='0006a69f'])
print("train_sample----")
display(train_sample.sort_values(['timestamp']))
print("")
display(train_sample[train_sample['event_code']==4100])
print("train_labels----")
display(train_labels[(train_labels['installation_id']=='0006a69f')])
# Out:
# test----
# Empty DataFrame
# Columns: [event_id, game_session, timestamp, event_data, installation_id, event_count, event_code, game_time, title, type, world]
# Index: []
# train_sample----
#     event_id      game_session                 timestamp  \
# 0   3bfd1a65  9501794defd84e4d  2019-08-06T20:34:53.812Z
# 1   db02c830  9501794defd84e4d  2019-08-06T20:34:53.872Z
# 2   a1e4395d  9501794defd84e4d  2019-08-06T20:34:53.878Z
# 3   28ed704e  9501794defd84e4d  2019-08-06T20:34:56.658Z
# 4   a52b92d5  9501794defd84e4d  2019-08-06T20:34:56.660Z
# 5   9d29771f  9501794defd84e4d  2019-08-06T20:34:56.663Z
# 6   c74f40cd  9501794defd84e4d  2019-08-06T20:34:57.286Z
# 7   28ed704e  9501794defd84e4d  2019-08-06T20:34:57.686Z
# 8   9d29771f  9501794defd84e4d  2019-08-06T20:34:57.687Z
# 9   c74f40cd  9501794defd84e4d  2019-08-06T20:34:58.207Z
# 10  28ed704e  9501794defd84e4d  2019-08-06T20:34:58.539Z
# 11  9d29771f  9501794defd84e4d  2019-08-06T20:34:58.542Z
# ...

# %%
display(specs[specs['event_id']=='25fa8af4'])
# Out:
#      event_id  \
# 143  25fa8af4
#
#                                                                                                                                                                                                                                                                              info  \
# 143  This event occurs when the player on the done button to submit a solution. It contains information about the mushrooms placed on the stumps and the correctness of the action. This event is used to calculate accuracy and to diagnose player strategies and understanding.
#
# ...
